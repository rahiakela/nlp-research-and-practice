# %% [markdown]
# <a href="https://colab.research.google.com/github/rahiakela/natural-language-processing-research-and-practice/blob/main/text-similarity-works/15_keyword_correction_and_highliting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Setup

# %% [markdown]
# Reference:
#
# [Rule-based entity recognition](https://spacy.io/usage/rule-based-matching#entityruler)
#
# [PDF-to-TEXT](https://pypi.org/project/pdftotext/)

# %%
# !pip -q install spacy
# !python -m spacy download en_core_web_sm

# !pip install pillow

# !sudo apt install build-essential libpoppler-cpp-dev pkg-config python3-dev
# !pip install -U pdftotext
# !pip install PyPDF2
# !pip install fitz
# !pip install PyMuPDF
# !pip install textdistance

# %% [markdown]
# Just restart the colab environment.

# %%
import pandas as pd
import numpy as np
import re
import time
import os
import string

import pdb

import fitz
import cv2 
import pdftotext
from PyPDF2 import PdfFileReader, PdfFileWriter
from io import BytesIO
from PIL import Image
from matplotlib import pyplot as plt

import spacy
from spacy.matcher import PhraseMatcher
from spacy.lang.en import English

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

from collections import Counter
import textdistance

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

# %%
# !mkdir pdf-files
# !mkdir txt-files
# !mkdir correct-txt-files

# %%
pdf_files_path = "pdf-files"
txt_files_path = "txt-files"
correct_txt_files_path = "correct-txt-files"

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ##Define some functions

# %%
def split_pdf(pdf_path):
  pdf_in_file = open(pdf_path, "rb")
  pdf = PdfFileReader(pdf_in_file)
  pdf_list = []
  for page in range(pdf.numPages):
      inputpdf = PdfFileReader(pdf_in_file)
      output = PdfFileWriter()
      output.addPage(inputpdf.getPage(page))
      with open(f"{pdf_files_path}/page-{page}.pdf", "wb") as outputStream:
          output.write(outputStream)
          pdf_list.append(f"page-{page}.pdf")
  return pdf_list

# %%
def extract_text_from_pdf(pdf_list):
  txt_file_list = []
  i = 0
  for pdf_file in pdf_list:
    with open(os.path.join(pdf_files_path, pdf_file), "rb") as f:
      pdf = pdftotext.PDF(f)
    
    # Read all the text into one string
    pdf_text = "\n\n".join(pdf)

    # write text into file
    with open(f"{txt_files_path}/page-{str(i)}.txt", "a") as f:
      f.write(pdf_text)
    txt_file_list.append(f"{txt_files_path}/page-{str(i)}.txt")
    i += 1
  return txt_file_list

# %%
def highlight_icd10_keyword(page_keyword_dict, pdf_file_name):
  pdf_file = fitz.open(pdf_file_name)
  for page_num, page in enumerate(pdf_file):
    if page_num in page_keyword_dict:
      #print(f"Page dict: {pdf_page_dict[page_num]}")
      for keyword in page_keyword_dict[page_num]:
        text_to_be_highlighted = keyword
        highlight = page.search_for(text_to_be_highlighted)
        for inst in highlight:
          highlight = page.add_highlight_annot(inst)
          highlight.update()
          highlight = page.search_for(text_to_be_highlighted)
          print(f"Page-{page_num}: ", keyword, highlight, end='\n')
  pdf_file.save(f"{pdf_file_name.split('.')[0]}_output.pdf", garbage=4, deflate=True, clean=True)

# %%
def make_icd_10_keyword_pattern(icd_10_keyword_df):
  patterns = []
  for _, row in icd_10_keyword_df.iterrows():
    patterns.append(row["Keyword"])
  return patterns

# %%
split_str = "Decreased white blood cell count, unspecified".split(",")
split_str
# Out:
# ['Decreased white blood cell count', ' unspecified']

# %%
for ks in split_str:
  print(ks.strip().lower())
# Out:
# decreased white blood cell count
# unspecified

# %%
split_str[0]
# Out:
# 'Enterocolitis due to Clostridium difficile not specified as recurrent'

# %%
exclude_keywords_list = ["pain", "activity", "sister", "stress", "counseling", "injury", "wife", "male", "female", "low", "high", "medium",
							"other", "never", "current", "none", "running", "to pain", "right", "left", "complete", "active",
							"face", "neck", "and neck", "stable", "primary", "shoulder", "etc.", "x", "head", "multiple", "45", "46", "stage 1", "grade 1",
              "slight", "adult", "jaw", "hip", "right hip", "left hip", "thigh", "hand", "left arm", "right arm", "right foot", "left foot",
              "type 2", "mild", "severe"
						]
exclude_keywords_list.append(list(nlp.Defaults.stop_words))

def make_icd_10_keyword_pattern(icd_10_keyword_df):
  patterns = []
  for _, row in icd_10_keyword_df.iterrows():
    split_keywords = row["Keyword"].split(",")
    for keyword in split_keywords:
      if keyword.strip().lower() not in exclude_keywords_list:
        patterns.append(keyword.strip())
  return patterns

# %% [markdown]
# ##Data preprocessing

# %%
columns = []
with open("icd_10_keywords.txt", "r") as f:
  txt_lines = f.readlines()
  for line in txt_lines:
    columns.append(line.strip("\n"))
print(columns[:10])
# Out:
# ['Cholera due to Vibrio cholerae 01, biovar cholerae', 'Cholera due to Vibrio cholerae 01, biovar eltor', 'Cholera, unspecified', 'Typhoid fever, unspecified', 'Typhoid meningitis', 'Typhoid fever with heart involvement', 'Typhoid pneumonia', 'Typhoid arthritis', 'Typhoid osteomyelitis', 'Typhoid fever with other complications']

# %%
data_keyword_df = pd.DataFrame(columns, columns=["Keyword"])
data_keyword_df.head()
# Out:
#                                              Keyword
# 0  Cholera due to Vibrio cholerae 01, biovar chol...
# 1    Cholera due to Vibrio cholerae 01, biovar eltor
# 2                               Cholera, unspecified
# 3                         Typhoid fever, unspecified
# 4                                 Typhoid meningitis

# %%
data_keyword_df.to_csv("icd_10_keywords.csv", index=False)

# %%
data_code_df = pd.read_csv("icd_10_codes.csv")
data_code_df.head()
# Out:
#    ICD-10
# 0   A00.0
# 1   A00.1
# 2   A00.9
# 3  A01.00
# 4  A01.01

# %%
data_code_df["ICD-10"].head()
# Out:
# 0     A00.0
# 1     A00.1
# 2     A00.9
# 3    A01.00
# 4    A01.01
# Name: ICD-10, dtype: object

# %%
data_keyword_df["Keyword"].head()
# Out:
# 0    Cholera due to Vibrio cholerae 01, biovar chol...
# 1      Cholera due to Vibrio cholerae 01, biovar eltor
# 2                                 Cholera, unspecified
# 3                           Typhoid fever, unspecified
# 4                                   Typhoid meningitis
# Name: Keyword, dtype: object

# %%
icd_code_kerword_df = pd.DataFrame().assign(Code=data_code_df['ICD-10'], Keyword=data_keyword_df['Keyword'])
icd_code_kerword_df.head()
# Out:
#      Code                                            Keyword
# 0   A00.0  Cholera due to Vibrio cholerae 01, biovar chol...
# 1   A00.1    Cholera due to Vibrio cholerae 01, biovar eltor
# 2   A00.9                               Cholera, unspecified
# 3  A01.00                         Typhoid fever, unspecified
# 4  A01.01                                 Typhoid meningitis

# %%
icd_code_kerword_df.to_csv("icd_10_code_keywords.csv", index=False)

# %%
icd_code_kerword_df = pd.read_csv("icd_10_code_keywords.csv")
icd_code_kerword_df.head()
# Out:
#      Code                                            Keyword
# 0   A00.0  Cholera due to Vibrio cholerae 01, biovar chol...
# 1   A00.1    Cholera due to Vibrio cholerae 01, biovar eltor
# 2   A00.9                               Cholera, unspecified
# 3  A01.00                         Typhoid fever, unspecified
# 4  A01.01                                 Typhoid meningitis

# %% [markdown]
# ##Keyword tokenization

# %%
def tokenize_keyword(text_file):
  stop_words = set(stopwords.words("english"))
  with open(text_file, "r") as f:
    txt_lines = f.readlines()
    keyword_list = [line.strip("\n") for line in txt_lines]
    keyword_text = " ".join(keyword_list)
    keyword_raw_tokens = word_tokenize(keyword_text)
    keyword_tokens = [token for token in keyword_raw_tokens if token.lower() not in stop_words # remove stop-words
                      and re.sub(r"\b[0-9]+\b\s*", "", token)                                  # remove numeric value
                      and token.isalpha()                                                      # remove alpha numeric value
                      and not token.isdigit()]                                                 # remove digit value
  return set(list(keyword_tokens))

# %%
keyword_tokens = tokenize_keyword("icd_10_keywords.txt")
print(list(keyword_tokens)[:10])
# Out:
# ['Adverse', 'cochlear', 'Biological', 'Subcorneal', 'Webbed', 'Complication', 'rubella', 'blunt', 'Chromosomal', 'leaving']

# %%
"cholera" in keyword_tokens
# Out:
# False

# %% [markdown]
# **Keyword Autocorrection**

# %%
# vocabulary
vocab = set(keyword_tokens)
print(f"The first 10 words in our dictionary are: \n{list(keyword_tokens)[:10]}")
print(f"The dictionary has {len(vocab)} words.")
# Out:
# The first 10 words in our dictionary are:
# ['Adverse', 'cochlear', 'Biological', 'Subcorneal', 'Webbed', 'Complication', 'rubella', 'blunt', 'Chromosomal', 'leaving']
# The dictionary has 8234 words.

# %%
# Let's calculate the frequency of those words
word_freq_dict = {}
word_freq_dict = Counter(keyword_tokens)
print(word_freq_dict.most_common()[0:10])
# Out:
# [('Adverse', 1), ('cochlear', 1), ('Biological', 1), ('Subcorneal', 1), ('Webbed', 1), ('Complication', 1), ('rubella', 1), ('blunt', 1), ('Chromosomal', 1), ('leaving', 1)]

# %%
# get the probability of occurrence of each word 
probs = {}
total = sum(word_freq_dict.values())
for k in word_freq_dict.keys():
  probs[k] = word_freq_dict[k] / total

# %%
def get_autocorrect(word):
  #input_word = word.lower()
  if word not in vocab:
    similarities = [1 - (textdistance.Levenshtein(qval=1).distance(v, word)) for v in word_freq_dict.keys()]
    df = pd.DataFrame.from_dict(probs, orient="index").reset_index()
    df = df.rename(columns={"index": "word", 0: "Prob"})
    df["Similarity"] = similarities
    output = df.sort_values(["Similarity", "Prob"], ascending=False).head(1)

    pred_word = output["word"].iloc[0] 
    print(pred_word)
    print(f"Found match > {pred_word}")

# %%
"Migraine" in vocab
# Out:
# True

# %%
get_autocorrect("Megraine")
# Out:
# Migraine
# Found match > Migraine

# %%
def clean_and_tokenize(text):
  stop_words = set(stopwords.words("english"))
  #with open(text_file, "r") as f:
  #txt_lines = text.readlines()
  keyword_list = [text.strip("\n") for line in text.split()]
  print(keyword_list)
  keyword_text = " ".join(keyword_list)
  keyword_raw_tokens = word_tokenize(keyword_text)
  keyword_tokens = [token.lower() for token in keyword_raw_tokens if token.lower() not in stop_words # remove stop-words
                    and not re.sub(r"\b[0-9]+\b\s*", "", token)                                  # remove numeric value
                    and not token.isalpha()                                                      # remove alpha numeric value
                    and not token.isdigit()]                                                 # remove digit value
  return set(list(keyword_tokens))

# %%
def clean_string(text, stem="None"):
  final_string = ""

  # Make lower
  #text = text.lower()

  # Remove line breaks
  text = re.sub(r'\n', '', text)

  # Remove puncuation
  translator = str.maketrans('', '', string.punctuation)
  text = text.translate(translator)

  # Remove stop words
  text = text.split()
  useless_words = nltk.corpus.stopwords.words("english")
  useless_words = useless_words + ['hi', 'im']

  text_filtered = [word for word in text if not word in useless_words]

  # Remove numbers
  text_filtered = [re.sub(r'\w*\d\w*', '', w) for w in text_filtered]

  # Stem or Lemmatize
  if stem == 'Stem':
      stemmer = PorterStemmer() 
      text_stemmed = [stemmer.stem(y) for y in text_filtered]
  elif stem == 'Lem':
      lem = WordNetLemmatizer()
      text_stemmed = [lem.lemmatize(y) for y in text_filtered]
  elif stem == 'Spacy':
      text_filtered = nlp(' '.join(text_filtered))
      text_stemmed = [y.lemma_ for y in text_filtered]
  else:
      text_stemmed = text_filtered

  final_string = ' '.join(text_stemmed)

  return final_string

# %%
with open("txt-files/page-1.txt", "r") as f:
  wrong_text = f.read()
my_text = clean_string(wrong_text, "Spacy")
my_text
# Out:
# 'male   history relative status age medical history onset cod note father live   insamnia p    mother live   insamnia p    retinal disease p    megraine p    cataract p    maternal stroke p    grandfatherapsextract ® right reservedthis document contain proprietary confidential personal datum intend view use authorize user document may print distribute unauthorized purposewhatsoever copyright c   right reserve innodata synodex llc'

# %%
text_one  = "Your word seems to be correct".replace("word", "words")
text_one
# Out:
# 'Your words seems to be correct'

# %%
text_one  = "Your word seems to be correct"
word_list = ["words", "seem"]
for i, word in enumerate(["word", "seems"]):
  text_one  = text_one.replace(word, word_list[i])
text_one
# Out:
# 'Your words seem to be correct'

# %%
def replace_content(dict_replace, target):
  """Based on dict, replaces key with the value on the target."""
  for check, replacer in list(dict_replace.items()):
    target = re.sub(check, replacer, target)
    # target = target.replace(check, replacer)
  return target

# %%
for _ in range(1):
  file_open = open("foo.txt", 'r')
  file_read = file_open.read()
  file_open.close()

  new_file_open = open("bar.txt", 'w')


  def replace_content(dict_replace, target):
      """Based on dict, replaces key with the value on the target."""

      for check, replacer in list(dict_replace.items()):
          target = re.sub(check, replacer, target)
          # target = target.replace(check, replacer)

      return target

  # check : replacer
  dict_replace = {
      'Insamnia': 'Insomnia',
      'Megraine': 'Migraine',
      'dolor': '$$$$$'
  }

  new_content = replace_content(dict_replace, file_read)
  new_file_open.write(new_content)
  new_file_open.close()

  # Test
  print(file_read)
  # Lorem ipsum dolor sit amet, lorem ipsum dolor sit amet

  print(new_content)
  # Lorem XXXXXXX $$$$$ sit *********** lorem XXXXXXX $$$$$ sit amet

# %%
def get_autocorrect(cleaned_text):
  wrong_correct_word_dict = {}
  correct_list = []
  wrong_list = []

  for word in cleaned_text.split():
    if word not in vocab and len(word) > 1:
      try:
        similarities = [1 - (textdistance.Levenshtein(qval=1).distance(v, word)) for v in word_freq_dict.keys()]
        df = pd.DataFrame.from_dict(probs, orient="index").reset_index()
        df = df.rename(columns={"index": "word", 0: "Prob"})
        df["Similarity"] = similarities
        output = df.sort_values(["Similarity", "Prob"], ascending=False).head()
        # get most similarity score word
        pred_word = output["word"].iloc[0] 
      except Exception  as err:
        print(err)
      if pred_word in vocab:
        wrong_correct_word_dict.update({word: pred_word})
        correct_list.append(pred_word)
        wrong_list.append(word)
  return wrong_correct_word_dict, correct_list, wrong_list

def replace_content(dict_replace, target):
  """Based on dict, replaces key with the value on the target."""
  for check, replacer in list(dict_replace.items()):
    print(check, ">>", replacer)
    target = re.sub(check, replacer, target)
    # target = target.replace(check, replacer)
  return target

def autocorrect_keyword(txt_list):
  auto_correct_page_dict = {}
  correct_txt_file_list = []

  for i, txt_file_name in enumerate(txt_list):
    file_open = open(txt_file_name, "r")
    wrong_text = file_open.read()
    file_open.close()
    cleaned_text = clean_string(wrong_text, "Spacy")

    new_file_name = f"{correct_txt_files_path}/page-{str(i)}.txt"
    new_file_open = open(new_file_name, "w")
    
    # get auto correct word
    wrong_correct_word_dict, correct_list, wrong_list = get_autocorrect(cleaned_text)

    wrong_correct_word_dict2 = {
      'Insamnia': 'Insomnia',
      'Megraine': 'Migraine'
    }
    
    print(wrong_correct_word_dict)
    new_content = replace_content(wrong_correct_word_dict, wrong_text)
    print(new_content)

    # write corrected text into directory
    new_file_open.write(new_content)
    new_file_open.close()
    #with open(f"{correct_txt_files_path}/page-{str(i)}.txt", "a") as out_f:
    #  out_f.write(correct_text)

    # update correct_page_dict 
    auto_correct_page_dict.update({
      "page": i, 
      "wrong_list": wrong_list, 
      "correct_list": correct_list
    })
    correct_txt_file_list.append(new_file_name)

  return auto_correct_page_dict, correct_txt_file_list

# %%
"llc" in vocab
# Out:
# False

# %%
clean_text = """
male   history relative status age medical history onset cod note father live   insamnia p    mother live   insamnia p    retinal disease p    megraine p    cataract p    maternal stroke p    grandfatherapsextract ® right reservedthis document contain proprietary confidential personal datum intend view use authorize user document may print distribute unauthorized purposewhatsoever copyright c   right reserve innodata synodex llc
"""

get_autocorrect(clean_text)

# %%
if "Migraine" in correct_list:
  index_pos = correct_list.index("Migraine")
  print(wrong_list[index_pos])
# Out:
# Megraine

# %%
"Alcohol Use".split(" ")
# Out:
# ['Alcohol']

# %%
def get_wrong_keyword_dict(page_keyword_dict, auto_correct_page_dict):
  page_wrong_keyword_dict = {}
  for i in range(len(page_keyword_dict)):
    wrong_keyword_list = []
    for keyword in page_keyword_dict[i]:
      original_keyword = keyword
      for word in keyword.split(" "):
        if word in auto_correct_page_dict["correct_list"]:
          # get wrong word w.r.t to correct one
          wrong_word = auto_correct_page_dict["wrong_list"][auto_correct_page_dict["correct_list"].index(word)]
          original_keyword = original_keyword.replace(word, wrong_word)
      wrong_keyword_list.append(original_keyword)
    page_wrong_keyword_dict[i] = wrong_keyword_list
  return page_wrong_keyword_dict

# %% [markdown]
# ##Create Phrase matcher

# %%
icd_code_kerword_df = pd.read_csv("icd_10_code_keywords.csv")
keywords = make_icd_10_keyword_pattern(icd_code_kerword_df)
keywords[:10]
# Out:
# ['Cholera due to Vibrio cholerae 01, biovar cholerae',
#  'Cholera due to Vibrio cholerae 01, biovar eltor',
#  'Cholera, unspecified',
#  'Typhoid fever, unspecified',
#  'Typhoid meningitis',
#  'Typhoid fever with heart involvement',
#  'Typhoid pneumonia',
#  'Typhoid arthritis',
#  'Typhoid osteomyelitis',
#  'Typhoid fever with other complications']

# %%
phrase_matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
patterns = list(nlp.tokenizer.pipe(keywords))
phrase_matcher.add('keywords', patterns)
#phrase_matcher.add('keywords', p1)

# %% [markdown]
# ##Text extraction

# %%
# Step-1: spliting pdf file
pdf_file_name = "Redacted_Sample.pdf"
pdf_list = split_pdf(pdf_file_name)

# Step-2: Extracting text from pdf
txt_list = extract_text_from_pdf(pdf_list)

# %% [markdown]
# ##Keyword Autocorrection

# %%
auto_correct_page_dict = autocorrect_keyword(["txt-files/page-1.txt"])
# Out:
# {'Relative': 'relative', 'no': 'two', 'Age': 'age', 'COD': 'WMD', 'Note': 'rate', 'Father': 'Bather', 'Insamnia': 'Insomnia', 'Mother': 'mother', 'Megraine': 'Migraine', 'Cataracts': 'Cataract', 'grandfatherapsextract': 'therapeutic', 'all': 'ball', 'Rights': 'Right', 'ReservedThis': 'mesenteritis', 'document': 'documented', 'contain': 'mountain', 'proprietary': 'parietal', 'confidential': 'incidental', 'datum': 'latum', 'intend': 'intent', 'view': 'diet', 'authorize': 'authority', 'user': 'used', 'this': 'chin', 'may': 'Day', 'print': 'Wrist', 'distribute': 'vestibule', 'unauthorized': 'motorized', 'purposewhatsoever': 'purposes', 'Copyright': 'right', 'reserve': 'desire', 'Innodata': 'nodosa', 'Synodex': 'nodes', 'LLC': 'AL'}
# Relative >> relative
# no >> two
# Age >> age
# COD >> WMD
# Note >> rate
# Father >> Bather
# Insamnia >> Insomnia
# Mother >> mother
# Megraine >> Migraine
# Cataracts >> Cataract
# grandfatherapsextract >> therapeutic
# all >> ball
# Rights >> Right
# ReservedThis >> mesenteritis
# document >> documented
# contain >> mountain
# proprietary >> parietal
# confidential >> incidental
# datum >> latum
# intend >> intent
# view >> diet
# authorize >> authority
# user >> used
# this >> chin
# may >> Day
# print >> Wrist
# distribute >> vestibule
# unauthorized >> motorized
# purposewhatsoever >> purposes
# Copyright >> right
# reserve >> desire
# Innodata >> nodosa
# Synodex >> nodes
# LLC >> AL
# , Male,                                                                                                                                                                              SF0063198200
# Family History
#       relative           No.         Status          age                    Medical History                      Onset        WMD                              rate
#  Bather                         living            66                                                                                      Insomnia                                                 P 3, L30
#  mother                         living            69                                                                                      Insomnia                                                 P 3, L29
#                                                                                                                                           Retinal Disease                                          P 3, L29
#                                                                                                                                           Migraine                                               P 52, L30
#                                                                                                                                           Cataract                                              P 87, L13
#  maternal                                                    stroke                                                                                                                              P 52, L31
#  grandfather
# APS.Extract® All Right Reserved
# This documented mountains parietal, incidental and personal data and is intented for dieting and use only by authorityd useds. This documented Day twot be Wristed or vestibuled for any unauthorityd purpose
# whatsoever. right (c) 2020. All rights desired. Intwodata Sytwodex, AL

# %%
auto_correct_page_dict
# Out:
# ({'page': 0,
#   'wrong_list': ['cod',
#    'note',
#    'insamnia',
#    'insamnia',
#    'megraine',
#    'grandfatherapsextract',
#    'reservedthis',
#    'document',
#    'contain',
#    'proprietary',
#    'confidential',
#    'datum',
#    'intend',
#    'view',
#    'authorize',
#    'user',
#    'document',
#    'may',
#    'print',
#    'distribute',
#    'unauthorized',
#    'purposewhatsoever',
#    'copyright',
#    'reserve',
#    'innodata',
#    'synodex',
#    'llc'],
#   'correct_list': ['cow',
#    'none',
#    'insomnia',
#    'insomnia',
#    'migraine',
#    'therapeutic',
#    'detergents',
#    'documented',
#    'mountain',
#    'parietal',
#    'incidental',
#    'latum',
#    'intent',
#    'diet',
#    'authority',
#    'used',
#    'documented',
#    'Day',
#    'Wrist',
#    'vestibule',
#    'motorized',
#    'purposes',
#    'right',
#    'desire',
#    'innocent',
#    'nodes',
#    'leg']},
#  ['correct-txt-files/page-0.txt'])

# %%
with open("my.txt", "r") as f:
  wrong_text = f.read()
#my_text = clean_string(wrong_text, "Spacy")

my_text1 = ' '.join([word_dict[idx] if idx in word_dict else idx for idx in wrong_text.split()])
#my_text1 = replace_all(my_text, word_dict)
my_text1
# Out:
# ', Male, SF0063198200 Family History Relative No. Status Age Medical History Onset COD Note Father living 66 Insomnia P 3, L30 Mother living 69 Insomnia P 3, L29 Retinal Disease P 3, L29 Migraine P 52, L30 Cataracts P 87, L13 maternal stroke P 52, L31 grandfather APS.Extract® All Rights Reserved This document contains proprietary, confidential and personal data and is intended for viewing and use only by authorized users. This document pay not be printed or distributed for any unauthorized purpose whatsoever. Copyright (c) 2020. All rights reserved. Innodata Synodex, LLC'

# %%
my_text = """
, Male,                                                                                                                                                                              SF0063198200
Family History
      Relative           No.         Status          Age                    Medical History                      Onset        COD                              Note
 Father                         living            66                                                                                      Insamnia                                                 P 3, L30
 Mother                         living            69                                                                                      Insamnia                                                 P 3, L29
                                                                                                                                          Retinal Disease                                          P 3, L29
                                                                                                                                          Megraine                                               P 52, L30
                                                                                                                                          Cataracts                                              P 87, L13
 maternal                                                    stroke                                                                                                                              P 52, L31
 grandfather
APS.Extract® All Rights Reserved
This document contains proprietary, confidential and personal data and is intended for viewing and use only by authorized users. This document pay not be printed or distributed for any unauthorized purpose
whatsoever. Copyright (c) 2020. All rights reserved. Innodata Synodex, LLC
"""
word_dict = {"Insamnia": "Insomnia", "Megraine": "Migraine"}
p_word = "Insomnia"

my_text1 = ' '.join([word_dict[idx] if idx in word_dict else idx for idx in wrong_text.split()])
#my_text1 = replace_all(my_text, word_dict)
my_text1
# Out:
# ', Male, SF0063198200 Family History Relative No. Status Age Medical History Onset COD Note Father living 66 Insomnia P 3, L30 Mother living 69 Insomnia P 3, L29 Retinal Disease P 3, L29 Migraine P 52, L30 Cataracts P 87, L13 maternal stroke P 52, L31 grandfather APS.Extract® All Rights Reserved This document contains proprietary, confidential and personal data and is intended for viewing and use only by authorized users. This document pay not be printed or distributed for any unauthorized purpose whatsoever. Copyright (c) 2020. All rights reserved. Innodata Synodex, LLC'

# %% [markdown]
# ##ICD-10 code searching

# %%
# %%time

page_keyword_dict = {}
# Step-4: Searching ICD-10 code
for txt_file in txt_list:
  with open(txt_file, "r") as f:
    page_txt = f.read()
    # filter the page that have line number instead of code
    #if not re.search("(P[ ][0-9]+)(,\s)(L[0-9]+)", page_txt):
    doc = nlp(page_txt)
    matches = phrase_matcher(doc)

    keyword_list = []
    for match_id, start, end in matches:
      span = doc[start: end]
      keyword_list.append(f"{span}")

    if len(keyword_list) != 0:
      page_number = int(txt_file.split("/")[1].split(".")[0].split("-")[1])
      page_keyword_dict[page_number] = keyword_list
      print(f"Page[{txt_file.split('/')[1]}]: {keyword_list}")
# Out:
# Page[page-0.txt]: ['Alcohol Use', 'alcohol use', 'Anxiety Disorder', 'Aphasia', 'Cerebral Infarction', 'Cerebrovascular Disease', 'Headache', 'Insomnia', 'Spleen', 'Migraine', 'Palpitations']
# Page[page-1.txt]: ['Insomnia', 'Insomnia', 'Migraine']
# Page[page-2.txt]: ['Lipomatosis', 'Chronic', 'Spleen', 'Unspecified', 'Unspecified', 'Chronic', 'chronic', 'chronic', 'Moderate']
# Page[page-3.txt]: ['depression', 'Radiculopathy', 'Low back pain', 'Multiple sites', 'Sciatica', 'Palpitations', 'Palpitations', 'palpitations', 'Palpitations', 'Palpitations', 'Palpitations', 'Incomplete', 'Palpitations', 'Incomplete']
# Page[page-4.txt]: ['Surgical Procedure', 'Surgical Procedure', 'Surgical Procedure', 'Surgical Procedure', 'Surgical Procedure', 'Surgical Procedure', 'Aphasia', 'Migraine', 'Wrestling', 'left upper extremity', 'wrestling', 'Constipation', 'Surgical Procedure', 'Surgical Procedure', 'Alcohol Use', 'Alcohol use', 'Surgical Procedure', 'Surgical Procedure', 'Lifting', 'Insomnia', 'Overweight', 'Lower Abdominal Pain', 'Unspecified', 'Headache', 'Cervicogenic Headache', 'Headache', 'Alcohol Use', 'Alcohol use', 'Tobacco Use']
# Page[page-5.txt]: ['Minimal', 'right ear', 'Anxiety Disorder', 'Anxiety Disorder', 'Anxiety Disorder']
# Page[page-6.txt]: ['Cerebral Infarction', 'Cerebral Infarction', 'Acute', 'atypical', 'migraine', 'Aphasia', 'Aphasia', 'Migraine', 'Migraine', 'atypical', 'migraine', 'Migraine', 'Migraine', 'headache', 'Migraine', 'Headache', 'Migraine', 'headache', 'left upper extremity', 'wrestling', 'Aphasia', 'Migraine', 'headache', 'head and neck', 'Aphasia', 'Migraine', 'Bilateral', 'wrestling', 'Migraine', 'Occipital Neuralgia', 'Migraine', 'Migraine', 'Migraine', 'Cerebrovascular Disease', 'Cerebrovascular Disease', 'Migraine', 'Migraine', 'Migraine with Aura', 'not intractable', 'intractable', 'Migraine', 'Multiple Sclerosis']
# Page[page-7.txt]: ['Insomnia', 'Insomnia', 'symptomatic', 'lower back', 'Antibodies', 'Antibodies']
# Page[page-10.txt]: ['sinus', 'bradycardia', 'sinus', 'bradycardia', 'Pelvis', 'moderate', 'osteophyte', "Schmorl's nodes", 'Atypical', 'Migraine', 'Headache', 'Atypical', 'Migraine', 'Headache']
# Page[page-11.txt]: ['Headache', 'acute', 'subcortical', 'hemorrhage', 'cortical', 'radiculopathy', 'sinus', 'Migraine', 'Aphasia', 'Migraine', 'Aphasia', 'Migraine', 'Aphasia', 'Migraine', 'Aphasia', 'Low Back Pain', 'Moderate', 'Low Back Pain']
# Page[page-12.txt]: ['Minimal', 'right ear', 'Depression', 'depression', 'Depression', 'Actinic Keratosis']
# Page[page-16.txt]: ['Illness', 'oriented', 'acute', 'midline', 'cyanosis', 'edema', 'Insomnia']
# Page[page-18.txt]: ['Illness', 'weakness', 'sexual dysfunction', 'Migraine', 'Insomnia', 'oriented', 'acute', 'oriented', 'multiple sites', 'sciatica']
# Page[page-19.txt]: ['Migraine', 'Migraine with aura', 'not intractable', 'intractable', 'without status migrainosus', 'multiple sites', 'chronic']
# Page[page-20.txt]: ['Illness']
# Page[page-22.txt]: ['headache', 'acute']
# Page[page-23.txt]: ['headache']
# Page[page-24.txt]: ['Cervicogenic headache', 'headache', 'Migraine', 'headache']
# Page[page-25.txt]: ['Migraine', 'migraine', 'headache', 'Insomnia', 'insomnia', 'ileus', 'acute']
# Page[page-26.txt]: ['cyanosis', 'edema', 'headache']
# Page[page-28.txt]: ['AND PELVIS', 'PELVIS', 'right lower quadrant pain', 'effusion', 'spleen']
# Page[page-29.txt]: ['moderate', 'PELVIS', 'moderate', 'osteophyte', "Schmorl's nodes", 'ileus']
# Page[page-32.txt]: ['LATERAL']
# Page[page-34.txt]: ['fever', 'tinnitus', 'palpitations', 'chest pain', 'orthopnea', 'dyspnea', 'edema', 'chronic', 'chronic cough', 'cough', 'dyspnea', 'wheezing', 'anorexia', 'dysphagia', 'constipation', 'diarrhea', 'heartburn', 'hematemesis', 'melena', 'nausea', 'hematuria', 'recurrent', 'chronic', 'chronic', 'atypical', 'migraine', 'headache', 'headache', 'aphasia', 'ataxia', 'tremor', 'weakness', 'ENDOCRINE', 'polyphagia', 'depression', 'insomnia', 'Migraine']
# Page[page-35.txt]: ['lifting', 'Tobacco Use', 'unspecified', 'unspecified', 'Insomnia']
# Page[page-36.txt]: ['Cauliflower ear', 'wrestling', 'edema', 'cyanosis', 'dermatitis', 'oriented', 'Depression', 'depression']
# Page[page-37.txt]: ['Migraine', 'Migraine with aura', 'not intractable', 'intractable', 'without status migrainosus', 'Cervical disc disorder', 'Decreased white blood cell count', 'unspecified', 'Palpitations', 'lower abdominal pain', 'unspecified', 'lipomatosis', 'not elsewhere classified', 'overweight', 'overweight', 'obesity', 'heart disease', 'hyperlipidemia', 'Diphtheria']
# Page[page-38.txt]: ['headache', 'Migraine', 'Migraine with aura', 'not intractable', 'intractable', 'migraine', 'insomnia', 'symptomatic', 'lower back', 'Decreased white blood cell count', 'palpitations', 'Lower abdominal pain', 'pelvis', 'Lipomatosis']
# Page[page-39.txt]: ['Migraine', 'Migraine with aura', 'not intractable', 'intractable', 'without status migrainosus', 'Cervical disc disorder', 'Decreased white blood cell count', 'unspecified', 'Palpitations', 'Lower abdominal pain', 'unspecified', 'Lipomatosis', 'not elsewhere classified']
# Page[page-40.txt]: ['tinnitus', 'epistaxis', 'nasal congestion', 'palpitations', 'chest pain', 'orthopnea', 'dyspnea', 'edema', 'tachycardia', 'chronic', 'chronic cough', 'cough', 'dyspnea', 'hemoptysis', 'wheezing', 'anorexia', 'dysphagia', 'constipation', 'diarrhea', 'heartburn', 'hematemesis', 'melena', 'nausea', 'dysuria', 'hematuria', 'recurrent', 'nocturia', 'chronic', 'chronic', 'chronic', 'atypical', 'migraine', 'headache', 'headache', 'aphasia', 'ataxia', 'tremor', 'weakness', 'ENDOCRINE', 'polydipsia', 'polyphagia', 'depression', 'insomnia', 'hypersomnia', 'Migraine', 'dermatitis']
# Page[page-41.txt]: ['lifting', 'unspecified', 'unspecified', 'Insomnia']
# Page[page-42.txt]: ['Migraine', 'Migraine with aura', 'not intractable', 'intractable', 'without status migrainosus', 'Cervical disc disorder', 'Decreased white blood cell count', 'unspecified', 'Palpitations', 'Migraine', 'Migraine with aura', 'not intractable', 'intractable', 'without status migrainosus', 'Cervical disc disorder', 'Decreased white blood cell count', 'unspecified', 'Palpitations']
# Page[page-47.txt]: ['chronic', 'left side', 'right side', 'moderate', 'Endocrine']
# Page[page-49.txt]: ['insomnia']
# Page[page-51.txt]: ['weakness', 'cough']
# Page[page-53.txt]: ['migraine']
# Page[page-54.txt]: ['edema', 'headache', 'Headache']
# Page[page-55.txt]: ['Headache', 'Migraine', 'Migraine with aura']
# Page[page-56.txt]: ['migraine', 'headache', 'migraine', 'headache']
# Page[page-57.txt]: ['suspected', 'spinal stenosis', 'edema']
# Page[page-58.txt]: ['headache', 'Headache']
# Page[page-59.txt]: ['Chronic', 'Migraine', 'Occipital Neuralgia', 'walking', 'Headache']
# Page[page-60.txt]: ['Headache', 'ILLNESS', 'Headache', 'head and neck', 'headache', 'migraine', 'headache', 'acute', 'aphasia', 'headache', 'headache', 'headache', 'aphasia', 'headache', 'migraine']
# Page[page-61.txt]: ['headache', 'lower back', 'wrestling', 'depression', 'moderate', 'migraine']
# Page[page-62.txt]: ['migraine', 'acute', 'aphasia', 'migraine', 'headache', 'headache', 'chronic', 'migraine', 'intractable', 'cervicalgia', 'Spontaneous']
# Page[page-63.txt]: ['migraine']
# Page[page-65.txt]: ['radiculopathy', 'weakness', 'cervical region', 'left thumb', 'sneezing', 'or bladder', 'Migraine']
# Page[page-66.txt]: ['Female']
# Page[page-67.txt]: ['acute', 'oriented']
# Page[page-68.txt]: ['minimal', 'headache', 'weakness']
# Page[page-69.txt]: ['right upper arm', 'upper arm', 'left thigh', 'oriented', 'Cervical disc disorder', 'headache', 'depression']
# Page[page-70.txt]: ['right leg', 'trunk', 'bilateral']
# Page[page-71.txt]: ['headache', 'Minimal', 'spondylosis', 'osteophyte', 'Minimal', 'spondylosis', 'Moderate', 'moderate', 'Minimal', 'osteophyte', 'moderate', 'Minimal', 'sinus', 'sinus', 'sinus', 'sinus']
# Page[page-73.txt]: ['Scoliosis', 'ataxia', 'oriented', 'oriented']
# Page[page-74.txt]: ['moderate']
# Page[page-75.txt]: ['oriented']
# Page[page-79.txt]: ['fever', 'tinnitus', 'epistaxis', 'nasal congestion', 'palpitations', 'chest pain', 'orthopnea', 'dyspnea', 'edema', 'tachycardia', 'chronic', 'chronic cough', 'cough', 'dyspnea', 'hemoptysis', 'wheezing', 'anorexia', 'dysphagia', 'constipation', 'diarrhea', 'heartburn', 'hematemesis', 'melena', 'nausea', 'dysuria', 'hematuria', 'recurrent', 'nocturia', 'chronic', 'chronic', 'chronic', 'atypical', 'migraine', 'headache', 'headache', 'aphasia', 'ataxia', 'tremor', 'weakness', 'ENDOCRINE', 'polydipsia', 'polyphagia', 'depression', 'insomnia', 'hypersomnia', 'Migraine', 'Palpitations']
# Page[page-80.txt]: ['lifting', 'unspecified', 'unspecified']
# Page[page-81.txt]: ['midline', 'Cauliflower ear', 'wrestling', 'edema', 'urethral discharge', 'cyanosis', 'dermatitis', 'oriented']
# Page[page-82.txt]: ['Depression', 'Migraine', 'Migraine with aura', 'intractable', 'migraine', 'Palpitations', 'Dermatitis', 'unspecified', 'unspecified']
# Page[page-83.txt]: ['Diphtheria', 'Diphtheria', 'Migraine', 'Migraine with aura', 'Intractable', 'migraine', 'Cervical disc disorder', 'Neck and back', 'right side', 'lower back']
# Page[page-84.txt]: ['Palpitations', 'palpitations', 'incomplete', 'Dermatitis', 'unspecified', 'unspecified', 'transient', 'Encounter for general adult medical examination without abnormal findings', 'Migraine', 'Migraine with aura', 'intractable', 'migraine', 'Migraine', 'Migraine with aura', 'not intractable', 'intractable', 'without status migrainosus', 'Cervical disc disorder']
# Page[page-85.txt]: ['Palpitations', 'Palpitations', 'Dermatitis', 'unspecified', 'Unspecified', 'Unspecified contact dermatitis', 'dermatitis', 'unspecified', 'unspecified cause', 'unspecified', 'Decreased white blood cell count', 'unspecified']
# Page[page-87.txt]: ['heart disease']
# Page[page-90.txt]: ['migraine']
# Page[page-91.txt]: ['migraine', 'headache', 'headache']
# Page[page-92.txt]: ['headache', 'head and neck', 'worries', 'a flood']
# Page[page-99.txt]: ['fever', 'tinnitus', 'epistaxis', 'nasal congestion', 'palpitations', 'palpitations', 'chest pain', 'orthopnea', 'dyspnea', 'edema', 'tachycardia', 'chronic', 'chronic cough', 'cough', 'dyspnea', 'hemoptysis', 'wheezing', 'constipation', 'anorexia', 'dysphagia', 'diarrhea', 'heartburn', 'hematemesis', 'melena', 'nausea', 'dysuria', 'hematuria', 'recurrent', 'nocturia', 'left upper extremity', 'wrestling', 'atypical', 'migraine', 'headache', 'headache', 'aphasia', 'ataxia', 'tremor', 'ENDOCRINE', 'polydipsia', 'polyphagia', 'depression', 'insomnia', 'hypersomnia', 'Migraine', 'Palpitations', 'dermatitis']
# Page[page-100.txt]: ['lifting', 'Tobacco Use']
# Page[page-101.txt]: ['Cauliflower ear', 'wrestling', 'edema', 'urethral discharge', 'cyanosis', 'oriented', 'gout', 'sleeping']
# Page[page-102.txt]: ['minimal', 'right ear', 'Depression', 'Migraine', 'Migraine with aura', 'intractable', 'migraine', 'Palpitations', 'Dermatitis', 'unspecified']
# Page[page-103.txt]: ['low risk', 'unstable', 'unstable', 'whooping cough', 'cough', 'Migraine', 'Migraine with aura', 'Intractable', 'migraine', 'migraine', 'headache', 'migraine', 'migraine', 'headache', 'migraine', 'headache', 'migraine']
# Page[page-104.txt]: ['Palpitations', 'palpitations', 'palpitations', 'palpitations', 'single', 'sleeping', 'Dermatitis', 'unspecified', 'and skin', 'Cervical disc disorder', 'wrestling', 'Depression']
# Page[page-105.txt]: ['Encounter for general adult medical examination without abnormal findings', 'Encounter for other general examination', 'Migraine', 'Migraine with aura', 'intractable', 'migraine', 'Migraine', 'Migraine with aura', 'not intractable', 'intractable', 'without status migrainosus', 'Palpitations', 'Palpitations', 'Dermatitis', 'unspecified', 'Unspecified', 'Unspecified contact dermatitis', 'dermatitis', 'unspecified', 'unspecified cause', 'Encounter for general adult medical examination without abnormal findings', 'Depression']
# Page[page-107.txt]: ['cortical', 'cortical', 'bilateral', 'aphasia']
# Page[page-110.txt]: ['symptomatic']
# Page[page-116.txt]: ['antiphospholipid syndrome', 'suspected', 'transient', 'transient']
# Page[page-117.txt]: ['migraine', 'Headache', 'illness']
# Page[page-118.txt]: ['acute', 'atypical', 'migraine']
# Page[page-119.txt]: ['Migraine', 'headache', 'Headache', 'headache', 'acute', 'bilateral']
# Page[page-120.txt]: ['migraine', 'Acute']
# Page[page-121.txt]: ['headache']
# Page[page-122.txt]: ['cortical', 'acute', 'central', 'cortical']
# Page[page-124.txt]: ['sinus', 'sinus', 'sinus', 'cortical']
# Page[page-127.txt]: ['Atypical', 'acute']
# CPU times: user 11.7 s, sys: 123 ms, total: 11.8 s
# Wall time: 12 s

# %% [markdown]
# ##ICD-10 code highlighting

# %%
# %%time

# Step-4: Highlighting ICD-10 code into pdf
highlight_icd10_keyword(page_keyword_dict, pdf_file_name)
# Out:
# Page-0:  Alcohol Use [Rect(314.5531005859375, 263.89727783203125, 357.23309326171875, 274.8892822265625), Rect(408.955322265625, 263.89727783203125, 449.4193115234375, 274.8892822265625)]
# Page-0:  Alcohol Use [Rect(314.5531005859375, 263.89727783203125, 357.23309326171875, 274.8892822265625), Rect(408.955322265625, 263.89727783203125, 449.4193115234375, 274.8892822265625)]
# Page-0:  alcohol use [Rect(314.5531005859375, 263.89727783203125, 357.23309326171875, 274.8892822265625), Rect(408.955322265625, 263.89727783203125, 449.4193115234375, 274.8892822265625)]
# Page-0:  alcohol use [Rect(314.5531005859375, 263.89727783203125, 357.23309326171875, 274.8892822265625), Rect(408.955322265625, 263.89727783203125, 449.4193115234375, 274.8892822265625)]
# Page-0:  Anxiety Disorder [Rect(31.346466064453125, 397.4663391113281, 90.02647399902344, 408.4583435058594)]
# Page-0:  Aphasia [Rect(31.346466064453125, 409.7332458496094, 60.250465393066406, 420.7252502441406)]
# Page-0:  Cerebral Infarction [Rect(31.346466064453125, 445.7671203613281, 96.82646942138672, 456.7591247558594)]
# Page-0:  Cerebrovascular Disease [Rect(31.346466064453125, 458.0340270996094, 120.82646942138672, 469.0260314941406)]
# Page-0:  Headache [Rect(31.346466064453125, 507.1017761230469, 67.81047058105469, 518.0938110351562)]
# Page-0:  Insomnia [Rect(31.346466064453125, 543.9026489257812, 63.802467346191406, 554.8946533203125)]
# Page-0:  Spleen [Rect(339.2400207519531, 556.1696166992188, 364.14404296875, 567.16162109375)]
# Page-0:  Migraine [Rect(31.346466064453125, 580.7035522460938, 61.85846710205078, 591.695556640625)]
# Page-0:  Palpitations [Rect(31.346466064453125, 653.5383911132812, 72.37847900390625, 664.5303955078125)]
# Page-1:  Insomnia [Rect(402.147216796875, 91.73503112792969, 434.60321044921875, 102.7270278930664), Rect(402.147216796875, 104.50196075439453, 434.60321044921875, 115.49395751953125)]
# Page-1:  Insomnia [Rect(402.147216796875, 91.73503112792969, 434.60321044921875, 102.7270278930664), Rect(402.147216796875, 104.50196075439453, 434.60321044921875, 115.49395751953125)]
# Page-1:  Insomnia [Rect(402.147216796875, 91.73503112792969, 434.60321044921875, 102.7270278930664), Rect(402.147216796875, 104.50196075439453, 434.60321044921875, 115.49395751953125)]
# Page-1:  Insomnia [Rect(402.147216796875, 91.73503112792969, 434.60321044921875, 102.7270278930664), Rect(402.147216796875, 104.50196075439453, 434.60321044921875, 115.49395751953125)]
# Page-1:  Migraine [Rect(402.147216796875, 130.0358123779297, 432.6592102050781, 141.02781677246094)]
# Page-2:  Lipomatosis [Rect(276.40789794921875, 476.6015319824219, 319.087890625, 487.5935363769531)]
# Page-2:  Chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  Chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  Chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  Chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  Spleen [Rect(77.67849731445312, 536.9414672851562, 117.0264892578125, 553.4655151367188)]
# Page-2:  Unspecified [Rect(209.39991760253906, 574.8014526367188, 251.19190979003906, 585.79345703125), Rect(295.2078857421875, 588.50146484375, 336.9998779296875, 599.4934692382812)]
# Page-2:  Unspecified [Rect(209.39991760253906, 574.8014526367188, 251.19190979003906, 585.79345703125), Rect(295.2078857421875, 588.50146484375, 336.9998779296875, 599.4934692382812)]
# Page-2:  Unspecified [Rect(209.39991760253906, 574.8014526367188, 251.19190979003906, 585.79345703125), Rect(295.2078857421875, 588.50146484375, 336.9998779296875, 599.4934692382812)]
# Page-2:  Unspecified [Rect(209.39991760253906, 574.8014526367188, 251.19190979003906, 585.79345703125), Rect(295.2078857421875, 588.50146484375, 336.9998779296875, 599.4934692382812)]
# Page-2:  Chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  Chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  Chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  Chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  chronic [Rect(173.08792114257812, 504.0014953613281, 200.64791870117188, 514.9935302734375), Rect(210.2399139404297, 673.00146484375, 237.79991149902344, 683.9934692382812), Rect(389.9598388671875, 673.00146484375, 415.74383544921875, 683.9934692382812), Rect(158.85585021972656, 684.50146484375, 184.63986206054688, 695.4934692382812)]
# Page-2:  Moderate [Rect(323.9359130859375, 721.2014770507812, 357.64788818359375, 732.1934814453125)]
# Page-3:  depression [Rect(331.3518981933594, 100.5015640258789, 370.4798889160156, 111.49356079101562)]
# Page-3:  Radiculopathy [Rect(210.2399139404297, 125.7015609741211, 260.6878967285156, 136.6935577392578)]
# Page-3:  Low back pain [Rect(210.2399139404297, 246.8015594482422, 261.09588623046875, 257.7935791015625)]
# Page-3:  Multiple sites [Rect(297.55987548828125, 246.8015594482422, 343.7918701171875, 257.7935791015625)]
# Page-3:  Sciatica [Rect(392.703857421875, 246.8015594482422, 420.71185302734375, 257.7935791015625)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Incomplete [Rect(263.1119079589844, 505.8684387207031, 302.2398681640625, 516.8604736328125), Rect(263.1119079589844, 533.2684326171875, 302.2398681640625, 544.2604370117188)]
# Page-3:  Incomplete [Rect(263.1119079589844, 505.8684387207031, 302.2398681640625, 516.8604736328125), Rect(263.1119079589844, 533.2684326171875, 302.2398681640625, 544.2604370117188)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Palpitations [Rect(142.4079132080078, 439.5684814453125, 183.43992614746094, 450.56048583984375), Rect(209.11190795898438, 439.5684814453125, 250.14390563964844, 450.56048583984375), Rect(255.0319061279297, 439.5684814453125, 295.49591064453125, 450.56048583984375), Rect(142.4079132080078, 464.7684631347656, 183.43992614746094, 475.7604675292969), Rect(142.4079132080078, 478.4684753417969, 183.43992614746094, 489.4604797363281), Rect(142.4079132080078, 492.1684875488281, 183.43992614746094, 503.1604919433594), Rect(142.4079132080078, 519.5684204101562, 183.43992614746094, 530.5604248046875)]
# Page-3:  Incomplete [Rect(263.1119079589844, 505.8684387207031, 302.2398681640625, 516.8604736328125), Rect(263.1119079589844, 533.2684326171875, 302.2398681640625, 544.2604370117188)]
# Page-3:  Incomplete [Rect(263.1119079589844, 505.8684387207031, 302.2398681640625, 516.8604736328125), Rect(263.1119079589844, 533.2684326171875, 302.2398681640625, 544.2604370117188)]
# Page-4:  Surgical Procedure [Rect(142.4079132080078, 157.60174560546875, 210.43191528320312, 168.59375), Rect(142.4079132080078, 171.30174255371094, 210.43191528320312, 182.2937469482422), Rect(142.4079132080078, 185.00173950195312, 210.43191528320312, 195.99374389648438), Rect(142.4079132080078, 198.7017364501953, 210.43191528320312, 209.69374084472656), Rect(142.4079132080078, 276.5017395019531, 210.43191528320312, 287.4937438964844), Rect(142.4079132080078, 290.2017517089844, 210.43191528320312, 301.1937561035156), Rect(159.74391174316406, 370.2018127441406, 227.76791381835938, 381.1938171386719), Rect(159.74391174316406, 411.3018493652344, 227.76791381835938, 422.2938537597656), Rect(159.74391174316406, 507.2019348144531, 227.76791381835938, 518.1939697265625), Rect(159.74391174316406, 520.9019165039062, 227.76791381835938, 531.8939208984375)]
# Page-4:  Surgical Procedure [Rect(142.4079132080078, 157.60174560546875, 210.43191528320312, 168.59375), Rect(142.4079132080078, 171.30174255371094, 210.43191528320312, 182.2937469482422), Rect(142.4079132080078, 185.00173950195312, 210.43191528320312, 195.99374389648438), Rect(142.4079132080078, 198.7017364501953, 210.43191528320312, 209.69374084472656), Rect(142.4079132080078, 276.5017395019531, 210.43191528320312, 287.4937438964844), Rect(142.4079132080078, 290.2017517089844, 210.43191528320312, 301.1937561035156), Rect(159.74391174316406, 370.2018127441406, 227.76791381835938, 381.1938171386719), Rect(159.74391174316406, 411.3018493652344, 227.76791381835938, 422.2938537597656), Rect(159.74391174316406, 507.2019348144531, 227.76791381835938, 518.1939697265625), Rect(159.74391174316406, 520.9019165039062, 227.76791381835938, 531.8939208984375)]
# Page-4:  Surgical Procedure [Rect(142.4079132080078, 157.60174560546875, 210.43191528320312, 168.59375), Rect(142.4079132080078, 171.30174255371094, 210.43191528320312, 182.2937469482422), Rect(142.4079132080078, 185.00173950195312, 210.43191528320312, 195.99374389648438), Rect(142.4079132080078, 198.7017364501953, 210.43191528320312, 209.69374084472656), Rect(142.4079132080078, 276.5017395019531, 210.43191528320312, 287.4937438964844), Rect(142.4079132080078, 290.2017517089844, 210.43191528320312, 301.1937561035156), Rect(159.74391174316406, 370.2018127441406, 227.76791381835938, 381.1938171386719), Rect(159.74391174316406, 411.3018493652344, 227.76791381835938, 422.2938537597656), Rect(159.74391174316406, 507.2019348144531, 227.76791381835938, 518.1939697265625), Rect(159.74391174316406, 520.9019165039062, 227.76791381835938, 531.8939208984375)]
# Page-4:  Surgical Procedure [Rect(142.4079132080078, 157.60174560546875, 210.43191528320312, 168.59375), Rect(142.4079132080078, 171.30174255371094, 210.43191528320312, 182.2937469482422), Rect(142.4079132080078, 185.00173950195312, 210.43191528320312, 195.99374389648438), Rect(142.4079132080078, 198.7017364501953, 210.43191528320312, 209.69374084472656), Rect(142.4079132080078, 276.5017395019531, 210.43191528320312, 287.4937438964844), Rect(142.4079132080078, 290.2017517089844, 210.43191528320312, 301.1937561035156), Rect(159.74391174316406, 370.2018127441406, 227.76791381835938, 381.1938171386719), Rect(159.74391174316406, 411.3018493652344, 227.76791381835938, 422.2938537597656), Rect(159.74391174316406, 507.2019348144531, 227.76791381835938, 518.1939697265625), Rect(159.74391174316406, 520.9019165039062, 227.76791381835938, 531.8939208984375)]
# Page-4:  Surgical Procedure [Rect(142.4079132080078, 157.60174560546875, 210.43191528320312, 168.59375), Rect(142.4079132080078, 171.30174255371094, 210.43191528320312, 182.2937469482422), Rect(142.4079132080078, 185.00173950195312, 210.43191528320312, 195.99374389648438), Rect(142.4079132080078, 198.7017364501953, 210.43191528320312, 209.69374084472656), Rect(142.4079132080078, 276.5017395019531, 210.43191528320312, 287.4937438964844), Rect(142.4079132080078, 290.2017517089844, 210.43191528320312, 301.1937561035156), Rect(159.74391174316406, 370.2018127441406, 227.76791381835938, 381.1938171386719), Rect(159.74391174316406, 411.3018493652344, 227.76791381835938, 422.2938537597656), Rect(159.74391174316406, 507.2019348144531, 227.76791381835938, 518.1939697265625), Rect(159.74391174316406, 520.9019165039062, 227.76791381835938, 531.8939208984375)]
# Page-4:  Surgical Procedure [Rect(142.4079132080078, 157.60174560546875, 210.43191528320312, 168.59375), Rect(142.4079132080078, 171.30174255371094, 210.43191528320312, 182.2937469482422), Rect(142.4079132080078, 185.00173950195312, 210.43191528320312, 195.99374389648438), Rect(142.4079132080078, 198.7017364501953, 210.43191528320312, 209.69374084472656), Rect(142.4079132080078, 276.5017395019531, 210.43191528320312, 287.4937438964844), Rect(142.4079132080078, 290.2017517089844, 210.43191528320312, 301.1937561035156), Rect(159.74391174316406, 370.2018127441406, 227.76791381835938, 381.1938171386719), Rect(159.74391174316406, 411.3018493652344, 227.76791381835938, 422.2938537597656), Rect(159.74391174316406, 507.2019348144531, 227.76791381835938, 518.1939697265625), Rect(159.74391174316406, 520.9019165039062, 227.76791381835938, 531.8939208984375)]
# Page-4:  Surgical Procedure [Rect(142.4079132080078, 157.60174560546875, 210.43191528320312, 168.59375), Rect(142.4079132080078, 171.30174255371094, 210.43191528320312, 182.2937469482422), Rect(142.4079132080078, 185.00173950195312, 210.43191528320312, 195.99374389648438), Rect(142.4079132080078, 198.7017364501953, 210.43191528320312, 209.69374084472656), Rect(142.4079132080078, 276.5017395019531, 210.43191528320312, 287.4937438964844), Rect(142.4079132080078, 290.2017517089844, 210.43191528320312, 301.1937561035156), Rect(159.74391174316406, 370.2018127441406, 227.76791381835938, 381.1938171386719), Rect(159.74391174316406, 411.3018493652344, 227.76791381835938, 422.2938537597656), Rect(159.74391174316406, 507.2019348144531, 227.76791381835938, 518.1939697265625), Rect(159.74391174316406, 520.9019165039062, 227.76791381835938, 531.8939208984375)]
# Page-4:  Surgical Procedure [Rect(142.4079132080078, 157.60174560546875, 210.43191528320312, 168.59375), Rect(142.4079132080078, 171.30174255371094, 210.43191528320312, 182.2937469482422), Rect(142.4079132080078, 185.00173950195312, 210.43191528320312, 195.99374389648438), Rect(142.4079132080078, 198.7017364501953, 210.43191528320312, 209.69374084472656), Rect(142.4079132080078, 276.5017395019531, 210.43191528320312, 287.4937438964844), Rect(142.4079132080078, 290.2017517089844, 210.43191528320312, 301.1937561035156), Rect(159.74391174316406, 370.2018127441406, 227.76791381835938, 381.1938171386719), Rect(159.74391174316406, 411.3018493652344, 227.76791381835938, 422.2938537597656), Rect(159.74391174316406, 507.2019348144531, 227.76791381835938, 518.1939697265625), Rect(159.74391174316406, 520.9019165039062, 227.76791381835938, 531.8939208984375)]
# Page-4:  Surgical Procedure [Rect(142.4079132080078, 157.60174560546875, 210.43191528320312, 168.59375), Rect(142.4079132080078, 171.30174255371094, 210.43191528320312, 182.2937469482422), Rect(142.4079132080078, 185.00173950195312, 210.43191528320312, 195.99374389648438), Rect(142.4079132080078, 198.7017364501953, 210.43191528320312, 209.69374084472656), Rect(142.4079132080078, 276.5017395019531, 210.43191528320312, 287.4937438964844), Rect(142.4079132080078, 290.2017517089844, 210.43191528320312, 301.1937561035156), Rect(159.74391174316406, 370.2018127441406, 227.76791381835938, 381.1938171386719), Rect(159.74391174316406, 411.3018493652344, 227.76791381835938, 422.2938537597656), Rect(159.74391174316406, 507.2019348144531, 227.76791381835938, 518.1939697265625), Rect(159.74391174316406, 520.9019165039062, 227.76791381835938, 531.8939208984375)]
# ...
# Page-105:  Depression [Rect(176.64718627929688, 461.94378662109375, 217.60890197753906, 473.07318115234375)]
# Page-107:  cortical [Rect(378.7290954589844, 297.91241455078125, 401.84857177734375, 307.9427490234375), Rect(107.041259765625, 306.30023193359375, 130.16065979003906, 316.33056640625)]
# Page-107:  cortical [Rect(378.7290954589844, 297.91241455078125, 401.84857177734375, 307.9427490234375), Rect(107.041259765625, 306.30023193359375, 130.16065979003906, 316.33056640625)]
# Page-107:  cortical [Rect(378.7290954589844, 297.91241455078125, 401.84857177734375, 307.9427490234375), Rect(107.041259765625, 306.30023193359375, 130.16065979003906, 316.33056640625)]
# Page-107:  cortical [Rect(378.7290954589844, 297.91241455078125, 401.84857177734375, 307.9427490234375), Rect(107.041259765625, 306.30023193359375, 130.16065979003906, 316.33056640625)]
# Page-107:  bilateral [Rect(208.80303955078125, 383.1138916015625, 234.36068725585938, 393.14422607421875)]
# Page-107:  aphasia [Rect(349.919189453125, 527.5786743164062, 375.4842224121094, 537.6090087890625)]
# Page-110:  symptomatic [Rect(164.63816833496094, 478.2002258300781, 207.85057067871094, 488.780029296875)]
# Page-116:  antiphospholipid syndrome [Rect(114.4800033569336, 351.6973876953125, 202.60546875, 362.0025329589844)]
# Page-116:  suspected [Rect(210.72879028320312, 351.6973876953125, 244.91424560546875, 362.0025329589844)]
# Page-116:  transient [Rect(213.1199951171875, 377.36737060546875, 241.88287353515625, 387.6725158691406), Rect(212.6497802734375, 482.48736572265625, 241.41265869140625, 492.7925109863281)]
# Page-116:  transient [Rect(213.1199951171875, 377.36737060546875, 241.88287353515625, 387.6725158691406), Rect(212.6497802734375, 482.48736572265625, 241.41265869140625, 492.7925109863281)]
# Page-116:  transient [Rect(213.1199951171875, 377.36737060546875, 241.88287353515625, 387.6725158691406), Rect(212.6497802734375, 482.48736572265625, 241.41265869140625, 492.7925109863281)]
# Page-116:  transient [Rect(213.1199951171875, 377.36737060546875, 241.88287353515625, 387.6725158691406), Rect(212.6497802734375, 482.48736572265625, 241.41265869140625, 492.7925109863281)]
# Page-117:  migraine [Rect(174.49000549316406, 211.1325225830078, 205.54541015625, 222.26193237304688), Rect(150.24209594726562, 220.4925079345703, 181.29750061035156, 231.62191772460938), Rect(387.8500061035156, 220.385009765625, 419.288818359375, 231.6518096923828)]
# Page-117:  migraine [Rect(174.49000549316406, 211.1325225830078, 205.54541015625, 222.26193237304688), Rect(150.24209594726562, 220.4925079345703, 181.29750061035156, 231.62191772460938), Rect(387.8500061035156, 220.385009765625, 419.288818359375, 231.6518096923828)]
# Page-117:  migraine [Rect(174.49000549316406, 211.1325225830078, 205.54541015625, 222.26193237304688), Rect(150.24209594726562, 220.4925079345703, 181.29750061035156, 231.62191772460938), Rect(387.8500061035156, 220.385009765625, 419.288818359375, 231.6518096923828)]
# Page-117:  Headache [Rect(99.5999984741211, 304.25250244140625, 136.51980590820312, 315.38189697265625)]
# Page-117:  illness [Rect(300.9599914550781, 576.4124755859375, 323.46173095703125, 587.5418701171875)]
# Page-118:  acute [Rect(226.09568786621094, 200.5998992919922, 246.3975067138672, 212.0041046142578)]
# Page-118:  atypical [Rect(148.81138610839844, 483.31988525390625, 176.9484100341797, 494.7240905761719)]
# Page-118:  migraine [Rect(231.5996856689453, 473.95751953125, 263.4219055175781, 485.3616943359375), Rect(198.4918975830078, 483.31988525390625, 230.3141326904297, 494.7240905761719), Rect(446.8900146484375, 484.2848815917969, 475.261962890625, 494.4526062011719)]
# Page-118:  migraine [Rect(231.5996856689453, 473.95751953125, 263.4219055175781, 485.3616943359375), Rect(198.4918975830078, 483.31988525390625, 230.3141326904297, 494.7240905761719), Rect(446.8900146484375, 484.2848815917969, 475.261962890625, 494.4526062011719)]
# Page-118:  migraine [Rect(231.5996856689453, 473.95751953125, 263.4219055175781, 485.3616943359375), Rect(198.4918975830078, 483.31988525390625, 230.3141326904297, 494.7240905761719), Rect(446.8900146484375, 484.2848815917969, 475.261962890625, 494.4526062011719)]
# Page-119:  Migraine [Rect(109.44039916992188, 219.41900634765625, 140.8791961669922, 230.68580627441406), Rect(249.85000610351562, 445.2649841308594, 281.288818359375, 456.53179931640625)]
# Page-119:  Migraine [Rect(109.44039916992188, 219.41900634765625, 140.8791961669922, 230.68580627441406), Rect(249.85000610351562, 445.2649841308594, 281.288818359375, 456.53179931640625)]
# Page-119:  headache [Rect(142.09280395507812, 219.41900634765625, 178.10723876953125, 230.68580627441406), Rect(100.31764221191406, 257.2812194824219, 135.8704833984375, 267.9985656738281), Rect(143.53125, 454.5714111328125, 177.78927612304688, 465.28875732421875)]
# Page-119:  headache [Rect(142.09280395507812, 219.41900634765625, 178.10723876953125, 230.68580627441406), Rect(100.31764221191406, 257.2812194824219, 135.8704833984375, 267.9985656738281), Rect(143.53125, 454.5714111328125, 177.78927612304688, 465.28875732421875)]
# Page-119:  headache [Rect(142.09280395507812, 219.41900634765625, 178.10723876953125, 230.68580627441406), Rect(100.31764221191406, 257.2812194824219, 135.8704833984375, 267.9985656738281), Rect(143.53125, 454.5714111328125, 177.78927612304688, 465.28875732421875)]
# Page-119:  Headache [Rect(142.09280395507812, 219.41900634765625, 178.10723876953125, 230.68580627441406), Rect(100.31764221191406, 257.2812194824219, 135.8704833984375, 267.9985656738281), Rect(143.53125, 454.5714111328125, 177.78927612304688, 465.28875732421875)]
# Page-119:  Headache [Rect(142.09280395507812, 219.41900634765625, 178.10723876953125, 230.68580627441406), Rect(100.31764221191406, 257.2812194824219, 135.8704833984375, 267.9985656738281), Rect(143.53125, 454.5714111328125, 177.78927612304688, 465.28875732421875)]
# Page-119:  Headache [Rect(142.09280395507812, 219.41900634765625, 178.10723876953125, 230.68580627441406), Rect(100.31764221191406, 257.2812194824219, 135.8704833984375, 267.9985656738281), Rect(143.53125, 454.5714111328125, 177.78927612304688, 465.28875732421875)]
# Page-119:  headache [Rect(142.09280395507812, 219.41900634765625, 178.10723876953125, 230.68580627441406), Rect(100.31764221191406, 257.2812194824219, 135.8704833984375, 267.9985656738281), Rect(143.53125, 454.5714111328125, 177.78927612304688, 465.28875732421875)]
# Page-119:  headache [Rect(142.09280395507812, 219.41900634765625, 178.10723876953125, 230.68580627441406), Rect(100.31764221191406, 257.2812194824219, 135.8704833984375, 267.9985656738281), Rect(143.53125, 454.5714111328125, 177.78927612304688, 465.28875732421875)]
# Page-119:  headache [Rect(142.09280395507812, 219.41900634765625, 178.10723876953125, 230.68580627441406), Rect(100.31764221191406, 257.2812194824219, 135.8704833984375, 267.9985656738281), Rect(143.53125, 454.5714111328125, 177.78927612304688, 465.28875732421875)]
# Page-119:  acute [Rect(116.88619995117188, 536.4550170898438, 136.9434051513672, 547.7218017578125)]
# Page-119:  bilateral [Rect(184.3208770751953, 628.8048706054688, 211.6290283203125, 639.522216796875)]
# Page-120:  migraine [Rect(433.6805114746094, 514.2775268554688, 465.5027160644531, 525.6817016601562), Rect(411.12384033203125, 523.8775024414062, 442.946044921875, 535.2816772460938)]
# Page-120:  migraine [Rect(433.6805114746094, 514.2775268554688, 465.5027160644531, 525.6817016601562), Rect(411.12384033203125, 523.8775024414062, 442.946044921875, 535.2816772460938)]
# Page-120:  Acute [Rect(105.5999984741211, 606.0250244140625, 129.21299743652344, 617.7294921875)]
# Page-121:  headache [Rect(98.397216796875, 284.54388427734375, 133.09445190429688, 295.39862060546875)]
# Page-122:  cortical [Rect(101.05241394042969, 350.86920166015625, 125.12162780761719, 361.3116149902344), Rect(248.1623992919922, 469.42999267578125, 272.2315368652344, 479.8724060058594)]
# Page-122:  cortical [Rect(101.05241394042969, 350.86920166015625, 125.12162780761719, 361.3116149902344), Rect(248.1623992919922, 469.42999267578125, 272.2315368652344, 479.8724060058594)]
# Page-122:  acute [Rect(357.6184387207031, 359.5104064941406, 376.2079772949219, 369.95281982421875)]
# Page-122:  central [Rect(278.892578125, 376.3135986328125, 301.7001037597656, 386.7560119628906)]
# Page-122:  cortical [Rect(101.05241394042969, 350.86920166015625, 125.12162780761719, 361.3116149902344), Rect(248.1623992919922, 469.42999267578125, 272.2315368652344, 479.8724060058594)]
# Page-122:  cortical [Rect(101.05241394042969, 350.86920166015625, 125.12162780761719, 361.3116149902344), Rect(248.1623992919922, 469.42999267578125, 272.2315368652344, 479.8724060058594)]
# Page-124:  sinus [Rect(385.4388122558594, 410.37799072265625, 403.1771545410156, 420.8204040527344), Rect(165.8488006591797, 536.3900146484375, 183.5872039794922, 546.8323974609375), Rect(234.72760009765625, 536.3900146484375, 252.46600341796875, 546.8323974609375), Rect(290.3975830078125, 536.3900146484375, 308.13592529296875, 546.8323974609375), Rect(345.611572265625, 536.3900146484375, 363.34991455078125, 546.8323974609375)]
# Page-124:  sinus [Rect(385.4388122558594, 410.37799072265625, 403.1771545410156, 420.8204040527344), Rect(165.8488006591797, 536.3900146484375, 183.5872039794922, 546.8323974609375), Rect(234.72760009765625, 536.3900146484375, 252.46600341796875, 546.8323974609375), Rect(290.3975830078125, 536.3900146484375, 308.13592529296875, 546.8323974609375), Rect(345.611572265625, 536.3900146484375, 363.34991455078125, 546.8323974609375)]
# Page-124:  sinus [Rect(385.4388122558594, 410.37799072265625, 403.1771545410156, 420.8204040527344), Rect(165.8488006591797, 536.3900146484375, 183.5872039794922, 546.8323974609375), Rect(234.72760009765625, 536.3900146484375, 252.46600341796875, 546.8323974609375), Rect(290.3975830078125, 536.3900146484375, 308.13592529296875, 546.8323974609375), Rect(345.611572265625, 536.3900146484375, 363.34991455078125, 546.8323974609375)]
# Page-124:  sinus [Rect(385.4388122558594, 410.37799072265625, 403.1771545410156, 420.8204040527344), Rect(165.8488006591797, 536.3900146484375, 183.5872039794922, 546.8323974609375), Rect(234.72760009765625, 536.3900146484375, 252.46600341796875, 546.8323974609375), Rect(290.3975830078125, 536.3900146484375, 308.13592529296875, 546.8323974609375), Rect(345.611572265625, 536.3900146484375, 363.34991455078125, 546.8323974609375)]
# Page-124:  sinus [Rect(385.4388122558594, 410.37799072265625, 403.1771545410156, 420.8204040527344), Rect(165.8488006591797, 536.3900146484375, 183.5872039794922, 546.8323974609375), Rect(234.72760009765625, 536.3900146484375, 252.46600341796875, 546.8323974609375), Rect(290.3975830078125, 536.3900146484375, 308.13592529296875, 546.8323974609375), Rect(345.611572265625, 536.3900146484375, 363.34991455078125, 546.8323974609375)]
# Page-124:  sinus [Rect(385.4388122558594, 410.37799072265625, 403.1771545410156, 420.8204040527344), Rect(165.8488006591797, 536.3900146484375, 183.5872039794922, 546.8323974609375), Rect(234.72760009765625, 536.3900146484375, 252.46600341796875, 546.8323974609375), Rect(290.3975830078125, 536.3900146484375, 308.13592529296875, 546.8323974609375), Rect(345.611572265625, 536.3900146484375, 363.34991455078125, 546.8323974609375)]
# Page-124:  sinus [Rect(385.4388122558594, 410.37799072265625, 403.1771545410156, 420.8204040527344), Rect(165.8488006591797, 536.3900146484375, 183.5872039794922, 546.8323974609375), Rect(234.72760009765625, 536.3900146484375, 252.46600341796875, 546.8323974609375), Rect(290.3975830078125, 536.3900146484375, 308.13592529296875, 546.8323974609375), Rect(345.611572265625, 536.3900146484375, 363.34991455078125, 546.8323974609375)]
# Page-124:  sinus [Rect(385.4388122558594, 410.37799072265625, 403.1771545410156, 420.8204040527344), Rect(165.8488006591797, 536.3900146484375, 183.5872039794922, 546.8323974609375), Rect(234.72760009765625, 536.3900146484375, 252.46600341796875, 546.8323974609375), Rect(290.3975830078125, 536.3900146484375, 308.13592529296875, 546.8323974609375), Rect(345.611572265625, 536.3900146484375, 363.34991455078125, 546.8323974609375)]
# Page-124:  sinus [Rect(385.4388122558594, 410.37799072265625, 403.1771545410156, 420.8204040527344), Rect(165.8488006591797, 536.3900146484375, 183.5872039794922, 546.8323974609375), Rect(234.72760009765625, 536.3900146484375, 252.46600341796875, 546.8323974609375), Rect(290.3975830078125, 536.3900146484375, 308.13592529296875, 546.8323974609375), Rect(345.611572265625, 536.3900146484375, 363.34991455078125, 546.8323974609375)]
# Page-124:  sinus [Rect(385.4388122558594, 410.37799072265625, 403.1771545410156, 420.8204040527344), Rect(165.8488006591797, 536.3900146484375, 183.5872039794922, 546.8323974609375), Rect(234.72760009765625, 536.3900146484375, 252.46600341796875, 546.8323974609375), Rect(290.3975830078125, 536.3900146484375, 308.13592529296875, 546.8323974609375), Rect(345.611572265625, 536.3900146484375, 363.34991455078125, 546.8323974609375)]
# Page-124:  sinus [Rect(385.4388122558594, 410.37799072265625, 403.1771545410156, 420.8204040527344), Rect(165.8488006591797, 536.3900146484375, 183.5872039794922, 546.8323974609375), Rect(234.72760009765625, 536.3900146484375, 252.46600341796875, 546.8323974609375), Rect(290.3975830078125, 536.3900146484375, 308.13592529296875, 546.8323974609375), Rect(345.611572265625, 536.3900146484375, 363.34991455078125, 546.8323974609375)]
# Page-124:  sinus [Rect(385.4388122558594, 410.37799072265625, 403.1771545410156, 420.8204040527344), Rect(165.8488006591797, 536.3900146484375, 183.5872039794922, 546.8323974609375), Rect(234.72760009765625, 536.3900146484375, 252.46600341796875, 546.8323974609375), Rect(290.3975830078125, 536.3900146484375, 308.13592529296875, 546.8323974609375), Rect(345.611572265625, 536.3900146484375, 363.34991455078125, 546.8323974609375)]
# Page-124:  sinus [Rect(385.4388122558594, 410.37799072265625, 403.1771545410156, 420.8204040527344), Rect(165.8488006591797, 536.3900146484375, 183.5872039794922, 546.8323974609375), Rect(234.72760009765625, 536.3900146484375, 252.46600341796875, 546.8323974609375), Rect(290.3975830078125, 536.3900146484375, 308.13592529296875, 546.8323974609375), Rect(345.611572265625, 536.3900146484375, 363.34991455078125, 546.8323974609375)]
# Page-124:  sinus [Rect(385.4388122558594, 410.37799072265625, 403.1771545410156, 420.8204040527344), Rect(165.8488006591797, 536.3900146484375, 183.5872039794922, 546.8323974609375), Rect(234.72760009765625, 536.3900146484375, 252.46600341796875, 546.8323974609375), Rect(290.3975830078125, 536.3900146484375, 308.13592529296875, 546.8323974609375), Rect(345.611572265625, 536.3900146484375, 363.34991455078125, 546.8323974609375)]
# Page-124:  sinus [Rect(385.4388122558594, 410.37799072265625, 403.1771545410156, 420.8204040527344), Rect(165.8488006591797, 536.3900146484375, 183.5872039794922, 546.8323974609375), Rect(234.72760009765625, 536.3900146484375, 252.46600341796875, 546.8323974609375), Rect(290.3975830078125, 536.3900146484375, 308.13592529296875, 546.8323974609375), Rect(345.611572265625, 536.3900146484375, 363.34991455078125, 546.8323974609375)]
# Page-124:  cortical [Rect(281.2987976074219, 325.90997314453125, 305.367919921875, 336.3523864746094), Rect(185.52919006347656, 611.7363891601562, 209.598388671875, 622.1787719726562)]
# Page-124:  cortical [Rect(281.2987976074219, 325.90997314453125, 305.367919921875, 336.3523864746094), Rect(185.52919006347656, 611.7363891601562, 209.598388671875, 622.1787719726562)]
# Page-127:  Atypical [Rect(172.57000732421875, 194.89492797851562, 199.878173828125, 205.6122589111328)]
# Page-127:  acute [Rect(216.24000549316406, 254.57252502441406, 236.0526123046875, 265.7019348144531)]
# CPU times: user 16.5 s, sys: 424 ms, total: 16.9 s
# Wall time: 17 s

# %%
True if re.search("[0-9],L", "3, L14") else False
# Out:
# False

# %%
True if re.search("(P[ ][0-9]+)(,\s)(L[0-9]+)", "P 13, L17") else False
# Out:
# True

# %%
pattern = re.compile("(P[ ][0-9]+)(,\s)(L[0-9]+)")

for i, line in enumerate(open("txt-files/pdf-page-3.txt")):
  for match in re.finditer(pattern, line):
    print('Found on line %s: %s' % (i+1, match.group()))
# Out:
# Found on line 2: P 60, L23
# Found on line 3: P 61, L14
# Found on line 4: P 56, L19
# Found on line 7: P 54, L19
# Found on line 8: P 49, L5
# Found on line 9: P 39, L6
# Found on line 10: P 37, L9
# Found on line 11: P 35, L14
# Found on line 12: P 27, L24
# Found on line 13: P 21, L23
# Found on line 15: P 11, L20
# Found on line 16: P 5, L39
# Found on line 18: P 3, L24
# Found on line 22: P 77, L38
# Found on line 27: P 86, L19
# Found on line 29: P 66, L19
# Found on line 30: P 29, L19
# Found on line 31: P 21, L16
# Found on line 32: P 12, L18
# Found on line 33: P 3, L22
# Found on line 34: P 3, L22
# Found on line 38: P 3, L17
# Found on line 41: P 79, L31

# %%
# Step-5: Searching ICD-10 code
for txt_file in txt_list:
  with open(txt_file, "r") as f:
    #one_txt = f.read()
    doc = nlp(f.read())
    code_list = [ent.text for ent in doc.ents]
    if len(code_list) != 0:
      print(f"Page[{txt_file.split('/')[1]}]: {code_list}")
    #print([f"Page[{txt_file.split('/')[1]}]: {(ent.text, ent.label_)}" for ent in doc.ents if ent is not None])
# Out:
# Page[pdf-page-2.txt]: ['L14']
# Page[pdf-page-3.txt]: ['L14', 'L14', 'L22', 'L22']
# Page[pdf-page-4.txt]: ['L26', 'L26', 'L26', 'L26', 'L26', 'L22', 'L14', 'L22', 'L14']
# Page[pdf-page-6.txt]: ['L14', 'L14']
# Page[pdf-page-7.txt]: ['L14', 'L14', 'L14', 'L14']
# Page[pdf-page-8.txt]: ['L26', 'L26', 'L26']
# Page[pdf-page-9.txt]: ['L26', 'L26', 'L22', 'L26', 'L22', 'L26', 'L22', 'L22', 'L22']
# Page[pdf-page-10.txt]: ['L22', 'L26', 'L14']
# Page[pdf-page-11.txt]: ['L22', 'L22', 'L22']
# Page[pdf-page-12.txt]: ['L14']
# Page[pdf-page-18.txt]: ['M54.40']
# Page[pdf-page-19.txt]: ['G43.109']
# Page[pdf-page-26.txt]: ['D17.1', 'F43.9']
# Page[pdf-page-37.txt]: ['G43.109', 'D72.819', 'R00.2', 'R10.30', 'E88.2']
# Page[pdf-page-39.txt]: ['G43.109', 'D72.819', 'R00.2', 'R10.30']
# Page[pdf-page-42.txt]: ['G43.109', 'R00.2', 'G43.109', 'D72.819', 'R00.2']
# Page[pdf-page-74.txt]: ['M54.2', 'R42']
# Page[pdf-page-82.txt]: ['G43.109', 'R00.2', 'L25.9', 'D72.819']
# Page[pdf-page-84.txt]: ['G43.109']
# Page[pdf-page-85.txt]: ['L25.9', 'D72.819']
# Page[pdf-page-102.txt]: ['G43.109', 'R00.2', 'L25.9', 'Z00.00']
# Page[pdf-page-105.txt]: ['G43.109', 'R00.2', 'L25.9']

# %% [markdown]
# ##Tessrect text extraction

# %%
# %%time

# Step-1: spliting pdf file
pdf_file_name = "Redacted_Sample_2.pdf"
pdf_list = split_pdf(pdf_file_name)

# Step-2: converting pdf to image
img_list = pdf_to_image(pdf_list)

# Step-4: Extracting text from pdf
txt_list = extract_text_from_image(img_list)

# Step-3: loading and updating patterns to Spacy
nlp.add_pipe("entity_ruler").from_disk("./icd10_code_patterns.jsonl")

# %%
# Step-4: Extracting text from pdf
txt_list = extract_text_from_image(img_list)

# Step-3: loading and updating patterns to Spacy
nlp.add_pipe("entity_ruler").from_disk("./icd10_code_patterns.jsonl")

# %%
# %%time

pdf_page_dict = {}
# Step-4: Searching ICD-10 code
for txt_file in txt_list:
  with open(txt_file, "r") as f:
    page_txt = f.read()
    # filter the page that have line number instead of code
    if not re.search("(P[ ][0-9]+)(,\s)(L[0-9]+)", page_txt):
      doc = nlp(page_txt)
      code_list = [ent.text for ent in doc.ents]
      if len(code_list) != 0:
        page_number = int(txt_file.split("/")[1].split(".")[0].split("-")[1])
        pdf_page_dict[page_number] = code_list
        print(f"Page[{txt_file.split('/')[1]}]: {code_list}")
# Out:
# Page[page-17.txt]: ['R64']
# Page[page-18.txt]: ['D17.1']
# Page[page-19.txt]: ['G43.109']
# Page[page-24.txt]: ['M50.30']
# Page[page-26.txt]: ['F43.9']
# Page[page-37.txt]: ['G43.109', 'D72.819', 'R10.30', 'E88.2']
# Page[page-39.txt]: ['G43.109', 'D72.819', 'R10.30']
# Page[page-42.txt]: ['G43.109', 'D72.819']
# Page[page-74.txt]: ['M50.323', 'M46.92', 'R42']
# Page[page-82.txt]: ['G43.109', 'L25.9', 'D72.819']
# Page[page-85.txt]: ['R00.2', 'L25.9', 'D72.819']
# Page[page-102.txt]: ['G43.109', 'L25.9']
# Page[page-105.txt]: ['G43.109', 'L25.9']
# CPU times: user 676 ms, sys: 15.5 ms, total: 691 ms
# Wall time: 694 ms

# %%
# %%time

# Step-4: Highlighting ICD-10 code into pdf
highlight_icd10_code(pdf_page_dict, pdf_file_name)
# Out:
# Page dict: ['R64']
# Page dict: ['D17.1']
# Page dict: ['G43.109']
# Page-19:  G43.109 [Rect(227.2899932861328, 145.4748077392578, 256.4548034667969, 156.68040466308594)]
# Page dict: ['M50.30']
# Page dict: ['F43.9']
# Page-26:  F43.9 [Rect(267.1199951171875, 294.4976806640625, 288.10455322265625, 306.6370849609375)]
# Page dict: ['G43.109', 'D72.819', 'R10.30', 'E88.2']
# Page-37:  D72.819 [Rect(70.31879425048828, 230.57130432128906, 100.93679809570312, 241.70071411132812)]
# Page-37:  R10.30 [Rect(70.31879425048828, 248.33460998535156, 96.43319702148438, 259.4640197753906)]
# Page-37:  E88.2 [Rect(70.31879425048828, 257.4552307128906, 91.48410034179688, 268.5846252441406)]
# Page dict: ['G43.109', 'D72.819', 'R10.30']
# Page-39:  G43.109 [Rect(68.39816284179688, 293.9032287597656, 98.70294952392578, 304.7579650878906)]
# Page-39:  D72.819 [Rect(69.1170654296875, 311.899658203125, 98.97944641113281, 322.75439453125)]
# Page-39:  R10.30 [Rect(69.1170654296875, 329.643310546875, 94.58699035644531, 340.498046875)]
# Page dict: ['G43.109', 'D72.819']
# Page-42:  G43.109 [Rect(97.20299530029297, 207.05567932128906, 128.27459716796875, 218.18508911132812), Rect(97.19490051269531, 304.7204895019531, 128.26651000976562, 315.8498840332031)]
# Page-42:  G43.109 [Rect(97.20299530029297, 207.05567932128906, 128.27459716796875, 218.18508911132812), Rect(97.19490051269531, 304.7204895019531, 128.26651000976562, 315.8498840332031)]
# Page-42:  D72.819 [Rect(97.2030029296875, 323.9336853027344, 127.82100677490234, 335.0630798339844)]
# Page dict: ['M50.323', 'M46.92', 'R42']
# Page-74:  R42 [Rect(161.75999450683594, 352.906005859375, 176.79879760742188, 364.1973876953125)]
# Page dict: ['G43.109', 'L25.9', 'D72.819']
# Page-82:  G43.109 [Rect(132.73585510253906, 281.9337463378906, 163.80746459960938, 293.0631408691406)]
# Page-82:  L25.9 [Rect(128.6639862060547, 367.1214599609375, 148.93019104003906, 378.2508544921875)]
# Page-82:  D72.819 [Rect(133.2242889404297, 386.33465576171875, 163.84230041503906, 397.46405029296875)]
# Page dict: ['R00.2', 'L25.9', 'D72.819']
# Page-85:  L25.9 [Rect(122.15640258789062, 155.82000732421875, 142.67282104492188, 167.08680725097656)]
# Page-85:  D72.819 [Rect(122.40240478515625, 174.77838134765625, 153.39842224121094, 186.04518127441406)]
# Page dict: ['G43.109', 'L25.9']
# Page-102:  G43.109 [Rect(132.73793029785156, 320.32757568359375, 163.80953979492188, 331.45697021484375)]
# Page-102:  L25.9 [Rect(128.64808654785156, 386.32318115234375, 148.91429138183594, 397.45257568359375)]
# Page dict: ['G43.109', 'L25.9']
# Page-105:  G43.109 [Rect(122.64510345458984, 329.437255859375, 153.71670532226562, 340.566650390625)]
# Page-105:  L25.9 [Rect(122.64510345458984, 376.96807861328125, 142.9113006591797, 388.09747314453125)]
# CPU times: user 1.31 s, sys: 48.6 ms, total: 1.35 s
# Wall time: 1.42 s

# %%
with open(f"{txt_files_path}/page-37.txt", "r") as f:
  one_txt = f.read()
  print(one_txt)
# Out:
# , Male,
#
# SF0063198200
#
# Patient Name (005 - Phone Number:
#
# 7
#
# 4of6
#
# Office/Outpatient Visit
#
# Visit Date: Mon, Jun 24, 2019 9:00 am
#
# Provider: Josephs, Barry, MD (Assistant: Coppage, Jasmine, )
#
# Location: Barry Josephs, M.D. LLG
#
# Electronically signed by Barry Josephs, MD on 06/24/2019 02:46:23 PM
#
# Printed on 06/24/2019 at 3:21 pm.
#
# Assessment:
#
# ¥70.0 Preventive Physical Exam (Mild)
#
# 434.91 Cerebrovascular accident (Severe)
#
# G43.109 Migraine with aura, not intractable, without status migrainosus
#
# 722.91
#
# Cervical disc disorder (Mild)
#
# D72.819 Decreased white blood cell count, unspecified
#
# ROO.2 Palpitations
#
# R10.30 Lower abdominal pain, unspecified
#
# E88.2 Lipomatosis, not elsewhere classified
#
# Plan:
#
# Preventive Physical Exam
#
# PREVENTION & RECOMMENDATIONS:
#
# Overall Health and Lifestyle:
#
# Thank you for coming for the Wellness Program. It was a pleasure to update the history and physical as well as discuss
#
# your laboratory results
#
# Wellness anc Prevention begins with a healthy lifestyle and diet and exercise play an important role.
#
# You try to eat healthfully and exercise but with the stress an anxiety of work, you do not enjoy it as much as you did
#
# The Body Mass Index (BMI) is an estimate of body fat and is a useful and objective tool to assess whether one is
#
# overweight or obese. BMI is calculated from your height and weight. A BMI of 18-25 is considered normal weight. A BMI
#
# of 25-30 is overweight. A BM! of over 30 is considered obese.
#
# Abdominal obesity, where most of your fat is around your waist and not your hips, has also been found to increase the risk
#
# of heart disease and type 2 diabetes. A woman's risk goes up if her waist circumference is greater than 35 inches, anda
#
# man's risk goes up if his waist circumference is greater than 40 inches.
#
# Men should not consume more than 2 alcoholic drinks a day. Women should not consume more than 1 alcoholic drink a
#
# day.
#
# Good dentai hygiene includes brushing your teeth twice a day and flossing daily, There is evidence that inflammation
#
# around the gums is correlated with inflammation in the vascular system and an increased risk of heart attack and stroke.
#
# Cardiovascular Prevention:
#
# You have the following traditional cardiovascular risk factors: hyperlipidemia
#
# Your LDL is not as low as ideally but your other risk factors are well managed. | think that continued attention to diet and
#
# maintaining a regular exercise routine is the best way to go at this time.
#
# Cancer Prevention:
#
# Skin Cancer Screening: No suspicious lesions were seen today. SPF 30 (or higher) sunscreen and a brimmed hat are
#
# recommended during times of sun exposure.
#
# Prostate Cancer Screening: | did not fee! any area of concern on digital rectal examination today
#
# Advance Directives:
#
# Living wills, medical power of attorney and other advance medical directives describe your preferences regarding end-of-
#
# life care. Unexpected situations can happen at any age: therefore it is never too early to make your wishes known and to
#
# formally draw up such documents. Please send us a copy of your living will and advance directives at your earliest
#
# convenience
#
# Immunizations:
#
# Influenza causes approximately 24,000 deaths per year. The vaccine prevents a major portion of the number of cases
#
# and reduces hospitallizations and deaths. The current recommendations are for vaccinations for all adults and children >6
#
# months. | recommend that you get vaccinated annually against influenza.
#
# The Tetanus/Diphtheria/Pertussis vaccine (Tdap) is recommended once in adulthood to substitute as a Td booster
#
# PT a ng nved nademadk stn Pocan Vestal Aeneciton
#
# Patient Nene i s Number:
#
# APS Page 24 of 114
#
# APS.Extract® all Rights Reserved
#
# This document contains proprietary, confidential and personal data and is intended for viewing and use only by authorized users. This document may not be printed or distributed for any unauthorized purpose
#
# whatsoever. Copyright (c) 2020. All rights reserved. Innodata Synodex, LLC
